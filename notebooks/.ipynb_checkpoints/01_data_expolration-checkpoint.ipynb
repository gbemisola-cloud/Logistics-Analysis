# %% [markdown]
# # Logistics Operations — Data Exploration
# **Project:** Logistics Capstone
# **Notebook:** 01 — Load & Explore All Sheets
# **Tools:** pandas
#
# ---
# **Goal:** Load all 14 sheets, understand their shape, spot any quality issues, and map the relationships before we start merging or analysing anything.

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd

# Show all columns when printing a DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.float_format', '{:,.2f}'.format)

print('pandas version:', pd.__version__)
# Out:
# pandas version: 2.3.3

# %% [markdown]
# ## 2. Load all 14 CSVs
#
# Each table is a separate CSV file in the `data/` folder.
# We load them directly into named DataFrames using `pd.read_csv()`.

# %%
import pandas as pd
import os

DATA_PATH = '../data/'  # relative path from notebooks/ folder

# Load all 14 CSVs
drivers          = pd.read_csv(DATA_PATH + 'drivers.csv')
trucks           = pd.read_csv(DATA_PATH + 'trucks.csv')
trailers         = pd.read_csv(DATA_PATH + 'trailers.csv')
customers        = pd.read_csv(DATA_PATH + 'customers.csv')
facilities       = pd.read_csv(DATA_PATH + 'facilities.csv')
routes           = pd.read_csv(DATA_PATH + 'routes.csv')
loads            = pd.read_csv(DATA_PATH + 'loads.csv')
trips            = pd.read_csv(DATA_PATH + 'trips.csv')
fuel_purchases   = pd.read_csv(DATA_PATH + 'fuel_purchases.csv')
maintenance      = pd.read_csv(DATA_PATH + 'maintenance_records.csv')
delivery_events  = pd.read_csv(DATA_PATH + 'delivery_events.csv')
safety_incidents = pd.read_csv(DATA_PATH + 'safety_incidents.csv')
driver_metrics   = pd.read_csv(DATA_PATH + 'driver_monthly_metrics.csv')
truck_metrics    = pd.read_csv(DATA_PATH + 'truck_utilization_metrics.csv')

print('All 14 tables loaded.')
# Out:
# All 14 tables loaded.

# %% [markdown]
# ## 3. Quick overview of every sheet
#
# This loop gives us a one-line summary for each table:
# how many rows, how many columns, and how many null values exist.

# %%
# Build a dict on the fly just for the overview loop
all_tables = {
    'DRIVERS':                  drivers,
    'TRUCKS':                   trucks,
    'TRAILERS':                 trailers,
    'CUSTOMERS':                customers,
    'FACILITIES':               facilities,
    'ROUTES':                   routes,
    'LOADS':                    loads,
    'TRIPS':                    trips,
    'FUEL_PURCHASES':           fuel_purchases,
    'MAINTENANCE_RECORDS':      maintenance,
    'DELIVERY_EVENTS':          delivery_events,
    'SAFETY_INCIDENTS':         safety_incidents,
    'DRIVER_MONTHLY_METRICS':   driver_metrics,
    'TRUCK_UTILIZATION_METRICS':truck_metrics,
}

print(f'{"Table":<35} {"Rows":>8} {"Cols":>6} {"Nulls":>8}')
print('-' * 62)
for name, df in all_tables.items():
    nulls = df.isnull().sum().sum()
    print(f'{name:<35} {df.shape[0]:>8,} {df.shape[1]:>6} {nulls:>8,}')
# Out:
# Table                                   Rows   Cols    Nulls
# --------------------------------------------------------------
# DRIVERS                                  150     12      124
# TRUCKS                                   120     11        0
# TRAILERS                                 180      9        0
# CUSTOMERS                                200      8        0
# FACILITIES                                50      9        0
# ROUTES                                    58      9        0
# LOADS                                 85,410     12        0
# TRIPS                                 85,410     12    5,066
# FUEL_PURCHASES                       196,442     11    7,868
# MAINTENANCE_RECORDS                    2,920     12        0
# DELIVERY_EVENTS                      170,820     11        0
# SAFETY_INCIDENTS                         170     15        2
# DRIVER_MONTHLY_METRICS                 4,464      9        0
# TRUCK_UTILIZATION_METRICS              3,312     10        0

# %% [markdown]
# ## 4. Deep dive — explore each table
#
# For every table we look at:
# - `.head()` — first 5 rows to see what data looks like
# - `.info()` — column names, data types, non-null counts
# - `.describe()` — stats for numeric columns
#
# Run each cell and **add notes** about anything that looks odd.

# %% [markdown]
# ### 4a. DRIVERS

# %%
print('Shape:', drivers.shape)
drivers.head()
# Out:
# Shape: (150, 12)
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# 1                20
# 2                19
# 3                19
# 4                12

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   driver_id          150 non-null    object
#  1   first_name         150 non-null    object
#  2   last_name          150 non-null    object
#  3   hire_date          150 non-null    object
#  4   termination_date   26 non-null     object
#  5   license_number     150 non-null    object
#  6   license_state      150 non-null    object
#  7   date_of_birth      150 non-null    object
#  8   home_terminal      150 non-null    object
#  9   employment_status  150 non-null    object
#  10  cdl_class          150 non-null    object
#  11  years_experience   150 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 14.2+ KB

# %%
drivers.describe()
# Out:
#        years_experience
# count            150.00
# mean              13.49
# std                6.96
# min                2.00
# 25%                7.25
# 50%               13.50
# 75%               20.00
# max               25.00

# %% [markdown]
# ### 4b. TRUCKS

# %%
print('Shape:', trucks.shape)
trucks.head()
# Out:
# Shape: (120, 11)
#    truck_id  unit_number          make  model_year                 vin  \
# 0  TRK00001         3463     Peterbilt        2016  1VV205190335317039
# 1  TRK00002         6461      Kenworth        2015  1NV753749606229960
# 2  TRK00003         2335     Peterbilt        2018  1NT803101860493229
# 3  TRK00004         3317  Freightliner        2015  1VV131945381692351
# 4  TRK00005         6731  Freightliner        2016  1FT822215709701985
#
#   acquisition_date  acquisition_mileage fuel_type  tank_capacity_gallons  \
# 0       2017-04-27                18814    Diesel                    200
# 1       2018-10-04                26795    Diesel                    150
# 2       2020-09-17                11795    Diesel                    150
# 3       2017-06-17                 8875    Diesel                    200
# 4       2021-10-08                42042    Diesel                    250
#
#         status   home_terminal
# 0       Active           Omaha
# 1       Active         Seattle
# 2  Maintenance         Atlanta
# 3       Active  Salt Lake City
# 4  Maintenance           Miami

# %%
trucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   truck_id               120 non-null    object
#  1   unit_number            120 non-null    int64
#  2   make                   120 non-null    object
#  3   model_year             120 non-null    int64
#  4   vin                    120 non-null    object
#  5   acquisition_date       120 non-null    object
#  6   acquisition_mileage    120 non-null    int64
#  7   fuel_type              120 non-null    object
#  8   tank_capacity_gallons  120 non-null    int64
#  9   status                 120 non-null    object
#  10  home_terminal          120 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 10.4+ KB

# %% [markdown]
# ### 4c. TRAILERS

# %%
print('Shape:', trailers.shape)
trailers.head()
# Out:
# Shape: (180, 9)
#   trailer_id  trailer_number  trailer_type  length_feet  model_year  \
# 0   TRL00001            4290  Refrigerated           53        2016
# 1   TRL00002            8848       Dry Van           53        2018
# 2   TRL00003            6147       Dry Van           53        2022
# 3   TRL00004            3910       Dry Van           53        2024
# 4   TRL00005            7524       Dry Van           53        2016
#
#                   vin acquisition_date  status current_location
# 0  1AV889081755621178       2018-05-11  Active      Kansas City
# 1  1BU942062588832828       2018-11-24  Active      Kansas City
# 2  1AV669057807416326       2019-01-28  Active        Milwaukee
# 3  1AV544000060905105       2018-08-27  Active         New York
# 4  1AV170126369813275       2019-11-22  Active        Las Vegas

# %% [markdown]
# ### 4d. CUSTOMERS

# %%
print('Shape:', customers.shape)
customers.head()
# Out:
# Shape: (200, 8)
#   customer_id          customer_name customer_type  credit_terms_days  \
# 0   CUST00001        Metro Wholesale     Dedicated                 60
# 1   CUST00002        National Retail      Contract                 30
# 2   CUST00003         XYZ Industries      Contract                 30
# 3   CUST00004          American Corp      Contract                 15
# 4   CUST00005  American Distribution          Spot                 45
#
#   primary_freight_type account_status contract_start_date  \
# 0              General       Inactive          2020-02-20
# 1               Retail         Active          2021-06-02
# 2       Consumer Goods         Active          2020-09-04
# 3        Food/Beverage         Active          2020-11-29
# 4       Consumer Goods         Active          2020-02-04
#
#    annual_revenue_potential
# 0                    985117
# 1                   4936566
# 2                   3102814
# 3                   3948027
# 4                   3682564

# %%
customers.describe()
# Out:
#        credit_terms_days  annual_revenue_potential
# count             200.00                    200.00
# mean               37.65              2,688,236.75
# std                17.08              1,454,956.50
# min                15.00                101,641.00
# 25%                30.00              1,405,872.00
# 50%                30.00              2,784,584.50
# 75%                60.00              3,859,272.50
# max                60.00              4,990,599.00

# %% [markdown]
# ### 4e. FACILITIES

# %%
print('Shape:', facilities.shape)
facilities.head()
# Out:
# Shape: (50, 9)
#   facility_id                  facility_name        facility_type  \
# 0    FAC00001    Houston Distribution Center           Cross-Dock
# 1    FAC00002                Kansas City Hub           Cross-Dock
# 2    FAC00003  Charlotte Distribution Center  Distribution Center
# 3    FAC00004    Chicago Distribution Center  Distribution Center
# 4    FAC00005               Indianapolis Hub  Distribution Center
#
#            city state  latitude  longitude  dock_doors operating_hours
# 0       Houston    TX     29.76     -95.37         125            24/7
# 1   Kansas City    MO     39.10     -94.58          33         7AM-7PM
# 2     Charlotte    NC     35.23     -80.84         138            24/7
# 3       Chicago    IL     41.88     -87.63          38         8AM-5PM
# 4  Indianapolis    IN     39.77     -86.16          56         8AM-5PM

# %% [markdown]
# ### 4f. ROUTES

# %%
print('Shape:', routes.shape)
routes.head()
# Out:
# Shape: (58, 9)
#    route_id origin_city origin_state destination_city destination_state  \
# 0  RTE00001     Atlanta           GA          Chicago                IL
# 1  RTE00002     Atlanta           GA            Miami                FL
# 2  RTE00003     Chicago           IL      Los Angeles                CA
# 3  RTE00004     Chicago           IL         Portland                OR
# 4  RTE00005     Chicago           IL        Las Vegas                NV
#
#    typical_distance_miles  base_rate_per_mile  fuel_surcharge_rate  \
# 0                     677                1.70                 0.19
# 1                     697                2.08                 0.22
# 2                    2003                2.55                 0.29
# 3                    2017                1.84                 0.19
# 4                    1749                2.41                 0.26
#
#    typical_transit_days
# 0                     1
# 1                     1
# 2                     3
# 3                     3
# 4                     3

# %%
routes.describe()
# Out:
#        typical_distance_miles  base_rate_per_mile  fuel_surcharge_rate  \
# count                   58.00               58.00                58.00
# mean                 1,391.50                2.20                 0.25
# std                    782.83                0.37                 0.06
# min                     92.00                1.52                 0.15
# 25%                    700.75                1.90                 0.19
# 50%                  1,271.00                2.23                 0.24
# 75%                  2,085.25                2.48                 0.30
# max                  3,141.00                2.79                 0.34
#
#        typical_transit_days
# count                 58.00
# mean                   2.12
# std                    1.16
# min                    1.00
# 25%                    1.00
# 50%                    2.00
# 75%                    3.00
# max                    5.00

# %% [markdown]
# ### 4g. LOADS  *(has foreign keys: customer_id, route_id)*

# %%
print('Shape:', loads.shape)
loads.head()
# Out:
# Shape: (85410, 12)
#         load_id customer_id  route_id   load_date     load_type  weight_lbs  \
# 0  LOAD00000001   CUST00183  RTE00019  2022-01-01       Dry Van       19178
# 1  LOAD00000002   CUST00076  RTE00058  2022-01-01       Dry Van       27761
# 2  LOAD00000003   CUST00027  RTE00048  2022-01-01  Refrigerated       35594
# 3  LOAD00000004   CUST00088  RTE00013  2022-01-01  Refrigerated       33274
# 4  LOAD00000005   CUST00185  RTE00020  2022-01-01       Dry Van       40257
#
#    pieces  revenue  fuel_surcharge  accessorial_charges load_status  \
# 0      13 3,045.23          406.72                  100   Completed
# 1      22 1,224.48           98.61                    0   Completed
# 2      16 7,171.12          792.88                    0   Completed
# 3      10 1,308.20          141.33                   50   Completed
# 4      10 3,317.18          738.48                    0   Completed
#
#   booking_type
# 0         Spot
# 1    Dedicated
# 2         Spot
# 3         Spot
# 4         Spot

# %%
loads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85410 entries, 0 to 85409
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   load_id              85410 non-null  object
#  1   customer_id          85410 non-null  object
#  2   route_id             85410 non-null  object
#  3   load_date            85410 non-null  object
#  4   load_type            85410 non-null  object
#  5   weight_lbs           85410 non-null  int64
#  6   pieces               85410 non-null  int64
#  7   revenue              85410 non-null  float64
#  8   fuel_surcharge       85410 non-null  float64
#  9   accessorial_charges  85410 non-null  int64
#  10  load_status          85410 non-null  object
#  11  booking_type         85410 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 7.8+ MB

# %%
loads.describe()

# %% [markdown]
# ### 4h. TRIPS  *(central table — joins to almost everything)*

# %%
print('Shape:', trips.shape)
trips.head()
# Out:
# Shape: (85410, 12)
#         trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0  TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1  TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2  TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3  TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4  TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
#
#    actual_distance_miles  actual_duration_hours  fuel_gallons_used  \
# 0                   1314                  26.20             183.80
# 1                    515                   8.60              93.60
# 2                   2509                  45.00             339.10
# 3                    717                  11.10             110.30
# 4                   2243                  35.00             328.90
#
#    average_mpg  idle_time_hours trip_status
# 0         7.15             3.50   Completed
# 1         5.50             8.30   Completed
# 2         7.40            12.00   Completed
# 3         6.50             9.60   Completed
# 4         6.82            11.60   Completed

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85410 entries, 0 to 85409
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_id                85410 non-null  object
#  1   load_id                85410 non-null  object
#  2   driver_id              83696 non-null  object
#  3   truck_id               83738 non-null  object
#  4   trailer_id             83730 non-null  object
#  5   dispatch_date          85410 non-null  object
#  6   actual_distance_miles  85410 non-null  int64
#  7   actual_duration_hours  85410 non-null  float64
#  8   fuel_gallons_used      85410 non-null  float64
#  9   average_mpg            85410 non-null  float64
#  10  idle_time_hours        85410 non-null  float64
#  11  trip_status            85410 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 7.8+ MB

# %%
trips.describe()
# Out:
#        actual_distance_miles  actual_duration_hours  fuel_gallons_used  \
# count              85,410.00              85,410.00          85,410.00
# mean                1,430.27                  25.01             221.83
# std                   801.93                  14.19             126.56
# min                    90.00                   1.40              12.00
# 25%                   717.00                  12.60             111.80
# 50%                 1,297.50                  23.00             204.50
# 75%                 2,147.00                  36.90             326.40
# max                 3,391.00                  67.80             611.90
#
#        average_mpg  idle_time_hours
# count    85,410.00        85,410.00
# mean          6.50             7.01
# std           0.58             2.88
# min           5.50             2.00
# 25%           6.00             4.50
# 50%           6.50             7.00
# 75%           7.00             9.50
# max           7.50            12.00

# %% [markdown]
# ### 4i. FUEL_PURCHASES

# %%
print('Shape:', fuel_purchases.shape)
fuel_purchases.head()
# Out:
# Shape: (196442, 11)
#   fuel_purchase_id       trip_id  truck_id driver_id        purchase_date  \
# 0     FUEL00000001  TRIP00051284  TRK00045  DRV00102  2023-10-22 05:00:00
# 1     FUEL00000002  TRIP00073723  TRK00013       NaN  2024-08-04 08:00:00
# 2     FUEL00000003  TRIP00018286  TRK00024  DRV00142  2022-08-23 13:00:00
# 3     FUEL00000004  TRIP00008465  TRK00018  DRV00047  2022-04-20 00:00:00
# 4     FUEL00000005  TRIP00069700  TRK00054       NaN  2024-06-13 09:00:00
#
#   location_city location_state  gallons  price_per_gallon  total_cost  \
# 0      Columbus             MN   131.60              3.40      447.31
# 1      New York             AZ   139.90              3.18      444.88
# 2       Seattle             NE   189.30              3.80      720.10
# 3       Memphis             NY   130.70              3.58      467.78
# 4      Columbus             AZ   185.30              3.42      634.10
#
#   fuel_card_number
# 0         FC567161
# 1         FC717910
# 2         FC912816
# 3         FC776357
# 4         FC391024

# %%
fuel_purchases.describe()
# Out:
#          gallons  price_per_gallon  total_cost
# count 196,442.00        196,442.00  196,442.00
# mean      124.82              3.90      486.62
# std        43.35              0.44      178.62
# min        50.00              3.15      158.50
# 25%        87.20              3.55      336.24
# 50%       124.70              3.86      480.66
# 75%       162.40              4.17      625.53
# max       200.00              5.00      997.90

# %% [markdown]
# ### 4j. MAINTENANCE_RECORDS

# %%
print('Shape:', maintenance.shape)
maintenance.head()
# Out:
# Shape: (2920, 12)
#   maintenance_id  truck_id maintenance_date maintenance_type  \
# 0  MAINT00000001  TRK00085       2022-01-01       Inspection
# 1  MAINT00000002  TRK00041       2022-01-01             Tire
# 2  MAINT00000003  TRK00090       2022-01-01       Preventive
# 3  MAINT00000004  TRK00056       2022-01-02       Inspection
# 4  MAINT00000005  TRK00029       2022-01-02           Repair
#
#    odometer_reading  labor_hours  labor_cost  parts_cost  total_cost  \
# 0            400255         7.80      781.42       10.41      791.83
# 1            268041         0.90       80.91    3,207.16    3,288.07
# 2            698915         7.20      733.18    1,570.57    2,303.75
# 3            416522         2.80      298.80       67.48      366.28
# 4            179968         4.60      409.08      982.59    1,391.67
#
#   facility_location  downtime_hours   service_description
# 0       Kansas City           22.20  Emergency Inspection
# 1           Seattle            8.00        Scheduled Tire
# 2             Miami           16.50    Routine Preventive
# 3       Kansas City           34.60  Emergency Inspection
# 4             Omaha            4.40      Emergency Repair

# %%
maintenance.describe()
# Out:
#        odometer_reading  labor_hours  labor_cost  parts_cost  total_cost  \
# count          2,920.00     2,920.00    2,920.00    2,920.00    2,920.00
# mean         401,534.79         4.18      438.53    1,524.00    1,962.53
# std          207,093.95         2.13      229.99    1,103.74    1,135.42
# min           50,156.00         0.50       43.28        0.14       60.82
# 25%          215,376.50         2.30      242.60      443.12      906.75
# 50%          407,955.00         4.20      435.20    1,465.41    1,896.05
# 75%          585,079.00         6.00      622.38    2,489.44    2,938.26
# max          749,875.00         8.00      976.87    3,498.61    4,426.57
#
#        downtime_hours
# count        2,920.00
# mean            24.74
# std             13.31
# min              2.00
# 25%             13.30
# 50%             24.75
# 75%             36.23
# max             48.00

# %% [markdown]
# ### 4k. DELIVERY_EVENTS

# %%
print('Shape:', delivery_events.shape)
delivery_events.head()
# Out:
# Shape: (170820, 11)
#       event_id       load_id       trip_id event_type facility_id  \
# 0  EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1  EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2  EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3  EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4  EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
#
#            scheduled_datetime             actual_datetime  detention_minutes  \
# 0  2022-01-01 18:00:00.000000  2022-01-01 20:58:55.918185                  0
# 1  2022-01-02 23:10:55.918185  2022-01-02 21:30:22.142060                230
# 2  2022-01-01 18:00:00.000000  2022-01-01 17:37:26.608430                 62
# 3  2022-01-02 02:13:26.608430  2022-01-02 05:55:46.238257                 67
# 4  2022-01-01 08:00:00.000000  2022-01-01 07:28:02.169634                 83
#
#    on_time_flag location_city location_state
# 0         False       Houston             TX
# 1          True       Detroit             MI
# 2          True   Kansas City             MO
# 3         False  Indianapolis             IN
# 4          True      Columbus             OH

# %%
delivery_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170820 entries, 0 to 170819
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   event_id            170820 non-null  object
#  1   load_id             170820 non-null  object
#  2   trip_id             170820 non-null  object
#  3   event_type          170820 non-null  object
#  4   facility_id         170820 non-null  object
#  5   scheduled_datetime  170820 non-null  object
#  6   actual_datetime     170820 non-null  object
#  7   detention_minutes   170820 non-null  int64
#  8   on_time_flag        170820 non-null  bool
#  9   location_city       170820 non-null  object
#  10  location_state      170820 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 13.2+ MB

# %% [markdown]
# ### 4l. SAFETY_INCIDENTS

# %%
print('Shape:', safety_incidents.shape)
safety_incidents.head()
# Out:
# Shape: (170, 15)
#    incident_id       trip_id  truck_id driver_id        incident_date  \
# 0  INC00000001  TRIP00036079  TRK00006  DRV00006  2023-04-09 14:00:00
# 1  INC00000002  TRIP00032462  TRK00084  DRV00006  2023-02-19 11:00:00
# 2  INC00000003  TRIP00067583  TRK00106  DRV00119  2024-05-20 01:00:00
# 3  INC00000004  TRIP00049128  TRK00085  DRV00134  2023-09-26 03:00:00
# 4  INC00000005  TRIP00062884  TRK00014  DRV00133  2024-03-20 14:00:00
#
#         incident_type location_city location_state  at_fault_flag  \
# 0    Moving Violation      Columbus             PA           True
# 1    Moving Violation      Columbus             NC          False
# 2  Customer Complaint       Seattle             OK           True
# 3    Equipment Damage   Kansas City             TN           True
# 4       DOT Violation     Las Vegas             IN          False
#
#    injury_flag  vehicle_damage_cost  cargo_damage_cost  claim_amount  \
# 0        False            12,629.26               0.00     12,629.26
# 1        False             2,700.70          14,284.24     16,984.94
# 2        False            24,302.32               0.00     24,302.32
# 3        False             4,879.13               0.00      4,879.13
# 4        False            14,951.40               0.00     14,951.40
#
#    preventable_flag                            description
# 0              True    Severe incident involving equipment
# 1             False      Severe incident involving weather
# 2              True       Minor incident involving traffic
# 3              True  Moderate incident involving equipment
# 4             False  Minor incident involving other driver

# %%
safety_incidents.describe()
# Out:
#        vehicle_damage_cost  cargo_damage_cost  claim_amount
# count               170.00             170.00        170.00
# mean              9,432.71           6,174.18     15,606.89
# std               8,549.03          12,989.25     15,082.13
# min                   0.00               0.00          0.00
# 25%                   0.00               0.00      2,108.28
# 50%               8,035.27               0.00     13,627.18
# 75%              17,688.74           1,790.56     21,988.79
# max              24,614.16          49,744.07     64,245.72

# %% [markdown]
# ### 4m. DRIVER_MONTHLY_METRICS  *(pre-aggregated — use for trends)*

# %%
print('Shape:', driver_metrics.shape)
driver_metrics.head()
# Out:
# Shape: (4464, 9)
#   driver_id       month  trips_completed  total_miles  total_revenue  \
# 0  DRV00001  2022-01-01               26        36620      79,141.59
# 1  DRV00001  2022-02-01                9        13515      27,133.87
# 2  DRV00001  2022-03-01               20        30361      62,399.62
# 3  DRV00001  2022-04-01               19        28127      68,161.13
# 4  DRV00001  2022-05-01               14        16071      36,256.82
#
#    average_mpg  total_fuel_gallons  on_time_delivery_rate  average_idle_hours
# 0         6.61            5,574.70                   0.39                8.20
# 1         6.69            2,095.10                   0.33                6.80
# 2         6.36            4,792.20                   0.55                7.50
# 3         6.61            4,251.40                   0.47                8.40
# 4         6.35            2,573.10                   0.21                6.80

# %%
driver_metrics.describe()
# Out:
#        trips_completed  total_miles  total_revenue  average_mpg  \
# count         4,464.00     4,464.00       4,464.00     4,464.00
# mean             18.75    26,812.79      57,630.95         6.50
# std               4.39     7,253.53      15,899.35         0.14
# min               5.00     3,310.00       7,096.56         6.01
# 25%              16.00    21,783.00      46,314.05         6.41
# 50%              19.00    26,409.50      56,652.71         6.50
# 75%              22.00    31,474.75      67,964.81         6.60
# max              37.00    57,954.00     124,579.53         7.07
#
#        total_fuel_gallons  on_time_delivery_rate  average_idle_hours
# count            4,464.00               4,464.00            4,464.00
# mean             4,158.63                   0.45                7.01
# std              1,132.04                   0.12                0.68
# min                521.90                   0.00                4.40
# 25%              3,372.50                   0.36                6.60
# 50%              4,083.95                   0.44                7.00
# 75%              4,882.40                   0.53                7.50
# max              9,007.50                   0.83                9.70

# %% [markdown]
# ### 4n. TRUCK_UTILIZATION_METRICS  *(pre-aggregated — use for fleet trends)*

# %%
print('Shape:', truck_metrics.shape)
truck_metrics.head()
# Out:
# Shape: (3312, 10)
#    truck_id       month  trips_completed  total_miles  total_revenue  \
# 0  TRK00001  2022-01-01               22        39269      84,792.02
# 1  TRK00001  2022-02-01               27        40787      88,809.05
# 2  TRK00001  2022-03-01               34        57422     120,453.71
# 3  TRK00001  2022-04-01               20        34428      73,531.28
# 4  TRK00001  2022-05-01               16        20851      40,791.53
#
#    average_mpg  maintenance_events  maintenance_cost  downtime_hours  \
# 0         6.78                   2          4,380.98           63.10
# 1         6.23                   0              0.00            0.00
# 2         6.49                   0              0.00            0.00
# 3         6.50                   2          3,548.15           71.80
# 4         6.38                   1          1,969.42           43.90
#
#    utilization_rate
# 0              0.71
# 1              0.96
# 2              1.10
# 3              0.67
# 4              0.52

# %%
truck_metrics.describe()
# Out:
#        trips_completed  total_miles  total_revenue  average_mpg  \
# count         3,312.00     3,312.00       3,312.00     3,312.00
# mean             25.28    36,152.23      77,700.56         6.50
# std               5.10     8,213.09      17,995.27         0.12
# min              11.00    12,680.00      27,876.18         6.01
# 25%              22.00    30,443.50      65,213.70         6.42
# 50%              25.00    35,758.00      76,607.69         6.50
# 75%              29.00    41,550.75      89,556.51         6.58
# max              46.00    71,177.00     144,891.10         6.86
#
#        maintenance_events  maintenance_cost  downtime_hours  utilization_rate
# count            3,312.00          3,312.00        3,312.00          3,312.00
# mean                 0.67          1,307.19           16.55              0.83
# std                  0.81          1,835.02           23.00              0.17
# min                  0.00              0.00            0.00              0.39
# 25%                  0.00              0.00            0.00              0.71
# 50%                  0.00              0.00            0.00              0.83
# 75%                  1.00          2,409.79           30.20              0.94
# max                  4.00         10,414.66          152.20              1.48

# %% [markdown]
# ## 5. Null value breakdown — per table
#
# We already saw the *total* nulls per table above.
# This cell shows which *columns* have nulls so we know what to fix in the cleaning notebook.

# %%
for name, df in all_tables.items():
    null_cols = df.isnull().sum()
    null_cols = null_cols[null_cols > 0]
    if len(null_cols) > 0:
        print(f'\n--- {name} ---')
        print(null_cols.to_string())

print('\nDone. Any table not listed above has zero nulls.')
# Out:
# --- DRIVERS ---
# termination_date    124
#
# --- TRIPS ---
# driver_id     1714
# truck_id      1672
# trailer_id    1680
#
# --- FUEL_PURCHASES ---
# truck_id     3880
# driver_id    3988
#
# --- SAFETY_INCIDENTS ---
# truck_id     1
# driver_id    1
#
# Done. Any table not listed above has zero nulls.

# %% [markdown]
# ## 6. Verify key relationships
#
# Before merging, we check that foreign keys actually match between tables.
# If the overlap is 100%, the join will be clean. If not, we have orphan records to investigate.
#
# Think of this as the pandas version of a SQL referential integrity check.

# %%
def check_fk(child_df, child_col, parent_df, parent_col, label):
    """Check how many FK values in child_df exist in parent_df."""
    child_vals  = set(child_df[child_col].dropna())
    parent_vals = set(parent_df[parent_col].dropna())
    matched     = child_vals & parent_vals
    pct         = len(matched) / len(child_vals) * 100 if child_vals else 0
    status      = 'OK' if pct == 100 else 'WARN'
    print(f'[{status}] {label}: {pct:.1f}% of {len(child_vals):,} values matched')

check_fk(loads,           'customer_id', customers,  'customer_id', 'loads -> customers')
check_fk(loads,           'route_id',    routes,     'route_id',    'loads -> routes')
check_fk(trips,           'load_id',     loads,      'load_id',     'trips -> loads')
check_fk(trips,           'driver_id',   drivers,    'driver_id',   'trips -> drivers')
check_fk(trips,           'truck_id',    trucks,     'truck_id',    'trips -> trucks')
check_fk(trips,           'trailer_id',  trailers,   'trailer_id',  'trips -> trailers')
check_fk(fuel_purchases,  'trip_id',     trips,      'trip_id',     'fuel_purchases -> trips')
check_fk(maintenance,     'truck_id',    trucks,     'truck_id',    'maintenance -> trucks')
check_fk(delivery_events, 'trip_id',     trips,      'trip_id',     'delivery_events -> trips')
check_fk(delivery_events, 'facility_id', facilities, 'facility_id', 'delivery_events -> facilities')
check_fk(safety_incidents,'trip_id',     trips,      'trip_id',     'safety_incidents -> trips')
# Out:
# [OK] loads -> customers: 100.0% of 200 values matched
# [OK] loads -> routes: 100.0% of 58 values matched
# [OK] trips -> loads: 100.0% of 85,410 values matched
# [OK] trips -> drivers: 100.0% of 124 values matched
# [OK] trips -> trucks: 100.0% of 92 values matched
# [OK] trips -> trailers: 100.0% of 180 values matched
# [OK] fuel_purchases -> trips: 100.0% of 76,939 values matched
# [OK] maintenance -> trucks: 100.0% of 120 values matched
# [OK] delivery_events -> trips: 100.0% of 85,410 values matched
# [OK] delivery_events -> facilities: 100.0% of 50 values matched
# [OK] safety_incidents -> trips: 100.0% of 170 values matched

# %% [markdown]
# ## 7. Notes & observations
#
# ### Dataset summary
# DRIVERS                —  150 rows,  12 cols,  124 nulls
# TRUCKS                 —  120 rows,  11 cols,    0 nulls
# TRAILERS               —  180 rows,   9 cols,    0 nulls
# CUSTOMERS              —  200 rows,   8 cols,    0 nulls
# FACILITIES             —   50 rows,   9 cols,    0 nulls
# ROUTES                 —   58 rows,   9 cols,    0 nulls
# LOADS                  — 85,410 rows, 12 cols,   0 nulls
# TRIPS                  — 85,410 rows, 12 cols, 5,066 nulls
# FUEL_PURCHASES         — 196,442 rows, 11 cols, 7,868 nulls
# MAINTENANCE_RECORDS    —  2,920 rows, 12 cols,   0 nulls
# DELIVERY_EVENTS        — 170,820 rows, 11 cols,  0 nulls
# SAFETY_INCIDENTS       —  170 rows,  15 cols,    2 nulls
# DRIVER_MONTHLY_METRICS —  4,464 rows,  9 cols,   0 nulls
# TRUCK_UTILIZATION_METRICS — 3,312 rows, 10 cols, 0 nulls
#
# ### Null columns
# - drivers.termination_date     → 124 nulls (drivers still employed — fill with "Active")
# - trips.driver_id              → 1,714 nulls (unassigned trips — drop for analysis)
# - trips.truck_id               → 1,672 nulls (unassigned trips — drop for analysis)
# - trips.trailer_id             → 1,680 nulls (unassigned trips — drop for analysis)
# - fuel_purchases.truck_id      → 3,880 nulls (drop for truck-level fuel analysis)
# - fuel_purchases.driver_id     → 3,988 nulls (drop for driver-level fuel analysis)
# - safety_incidents.truck_id    → 1 null (drop row)
# - safety_incidents.driver_id   → 1 null (drop row)
#
# ### FK integrity
# All 11 relationships checked — 100% matched. No orphan records.
#
# ### Issues to fix in 02_cleaning.ipynb
# 1. Fill termination_date nulls with "Active"
# 2. Drop trips rows where driver_id / truck_id / trailer_id is null
# 3. Drop fuel_purchases rows where truck_id or driver_id is null
# 4. Drop the 2 safety_incidents rows with nulls

# %% [markdown]
# ---
# **Next notebook:** `02_cleaning.ipynb` — fix nulls, data types, and prepare merge-ready tables.
